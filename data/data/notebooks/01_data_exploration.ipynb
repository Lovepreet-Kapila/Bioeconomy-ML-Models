# %% [markdown]
# # Bioeconomy ML — Data Exploration
#
# Initial exploratory data analysis (EDA) for bioeconomy machine learning project.
#
# Goals:
# - Load dataset
# - Explore features
# - Basic statistics & visualizations

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

pd.set_option('display.max_columns', None)

# %%
data_path = "../data/sample.csv"

try:
    df = pd.read_csv(data_path)
    df.head()
except FileNotFoundError:
    print("Dataset not found. Add dataset to data/ folder as sample.csv")
# Out:
# Dataset not found. Add dataset to data/ folder as sample.csv
